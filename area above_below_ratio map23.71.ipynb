# %%
import numpy as np
import matplotlib.pyplot as plt
from mpdaf.obj import Cube
import astropy.units as u
import plotly.express as px
import warnings
import astropy
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS

# Ignore warnings
warnings.filterwarnings('ignore', category=astropy.wcs.FITSFixedWarning)
warnings.filterwarnings('ignore', category=UserWarning, message="Warning: converting a masked element to nan.")

ra_deg = 258.4353666666666 
dec_deg = -37.10326666666667  

cube_path = '/Users/mary/Fits image of JWST/ngc6302_ch4-medium_s3d.fits'
obj1 = Cube(cube_path)
wcs = obj1.wcs.wcs  
skycoord = SkyCoord(ra=ra_deg*u.degree, dec=dec_deg*u.degree, frame='icrs')
pixcoords = wcs.world_to_pixel(skycoord)
pixel_x, pixel_y = int(pixcoords[0]), int(pixcoords[1])
central_star_coords = (pixel_x, pixel_y)
pixel_size = obj1.wcs.get_step(unit=u.arcsec)[0]
solid_angle = (pixel_size * u.arcsec).to(u.rad)**2
#The negative area above continuum line of these pixel with change the range of continuum became posative
specific_pixels = [(42, 36), (42, 35), (44, 36),(44,35),(43,35),(43,36),(47,35), (25,61),(45, 36), (45, 35), (46, 36), (46, 35), (46, 34), (47, 34)]

def process_pixel_data(cube, solid_angle, central_star_coords):
    wavelength = cube.wave.coord()
    mask_range = (wavelength >= 22.4) & (wavelength <= 24.05)
    filtered_wavelengths = wavelength[mask_range]

    area_above_continuum_map = np.zeros((cube.shape[1], cube.shape[2]))
    area_below_continuum_map = np.zeros((cube.shape[1], cube.shape[2]))
    ratio_map = np.zeros((cube.shape[1], cube.shape[2]))

    negative_area_pixels = []
    for x in range(cube.shape[1]):
        for y in range(cube.shape[2]):
            pixel_flux_density = cube.data[:, x, y] * solid_angle.value * 1e6
            filtered_pixel_flux_density = pixel_flux_density[mask_range]

            if (x, y) in specific_pixels:
                mask_start = (filtered_wavelengths >= 22.66) & (filtered_wavelengths <= 22.86)
                mask_end = (filtered_wavelengths >= 23.52) & (filtered_wavelengths <= 23.72)
                wavelengths = [22.76, 23.62]
            else:
                mask_start = (filtered_wavelengths >= 22.35) & (filtered_wavelengths <= 22.45)
                mask_end = (filtered_wavelengths >= 24) & (filtered_wavelengths <= 24.1)
                wavelengths = [22.4, 24.05]

            continuum_start = np.mean(filtered_pixel_flux_density[mask_start])
            continuum_end = np.mean(filtered_pixel_flux_density[mask_end])
            average_intensities = [continuum_start, continuum_end]
            pixel_continuum_line = np.interp(filtered_wavelengths, wavelengths, average_intensities)

            total_area = np.trapz(filtered_pixel_flux_density, filtered_wavelengths)
            area_below_continuum = np.trapz(pixel_continuum_line, filtered_wavelengths)
            area_above_continuum = total_area - area_below_continuum

            area_above_continuum_map[x, y] = area_above_continuum
            area_below_continuum_map[x, y] = area_below_continuum

            # Calculate the ratio
            if area_below_continuum != 0  and area_above_continuum > 0 :
                ratio_map[x, y] = area_above_continuum / area_below_continuum
            else:
                ratio_map[x, y] = np.nan
                
            if area_above_continuum < 0 :
                ratio_map[x, y] = np.nan  

    ratio_map *= 100

    np.savetxt('23.71area_above_continuum.txt', area_above_continuum_map, fmt='%.6f')
    np.savetxt('23.71area_below_continuum.txt', area_below_continuum_map, fmt='%.6f')
    np.savetxt('23.71ratio_map.txt', ratio_map, fmt='%.6f')

    plt.figure(figsize=(10, 8))
    plt.imshow(area_above_continuum_map, cmap='viridis', origin='lower')
    plt.colorbar(label='Area Above Continuum (Jy*µm)')
    plt.title('Map of Area Above Continuum')
    plt.contour(area_above_continuum_map, colors='white', alpha=0.5)
    plt.scatter(*central_star_coords, color='red', marker='*', s=100, label=' 2024')
    plt.legend()
    plt.savefig('23.71area_above_continuum_map.png', dpi=300, bbox_inches='tight')
    plt.show()

    plt.figure(figsize=(10, 8))
    plt.imshow(area_below_continuum_map, cmap='viridis', origin='lower')
    plt.colorbar(label='Area Below Continuum (Jy*µm)')
    plt.title('Map of Area Below Continuum')
    plt.contour(area_below_continuum_map, colors='white', alpha=0.5)
    plt.scatter(*central_star_coords, color='red', marker='*', s=100, label='2024')
    plt.legend()
    plt.savefig('23.71area_below_continuum_map.png', dpi=300, bbox_inches='tight')
    plt.show()

    plt.figure(figsize=(10, 8))
    plt.imshow(ratio_map, cmap='viridis', origin='lower')
    plt.colorbar(label='Ratio')
    plt.title('Map of Ratio ')
    plt.contour(ratio_map, colors='white', alpha=0.5)
    plt.scatter(*central_star_coords, color='red', marker='*', s=100, label='2024')
    plt.legend()
    plt.savefig('23.71ratio_map.png', dpi=300, bbox_inches='tight')
    plt.show()

    fig = px.imshow(area_above_continuum_map, color_continuous_scale='viridis', origin='lower',
                    labels={'color': 'Area Above Continuum (Jy*µm)'})
    fig.update_layout(title='1 Map of Area Above Continuum', coloraxis_colorbar=dict(title='Area Above Continuum (Jy*µm)'))
    fig.add_annotation(x=central_star_coords[1], y=central_star_coords[0], text=f"{area_above_continuum_map[central_star_coords[0], central_star_coords[1]]:.6f}", showarrow=True, arrowhead=1)
    fig.show()

    fig = px.imshow(area_below_continuum_map, color_continuous_scale='viridis', origin='lower',
                    labels={'color': 'Area Below Continuum (Jy*µm)'})
    fig.update_layout(title='2 Map of Area Below Continuum', coloraxis_colorbar=dict(title='Area Below Continuum (Jy*µm)'))
    fig.add_annotation(x=central_star_coords[1], y=central_star_coords[0], text=f"{area_below_continuum_map[central_star_coords[0], central_star_coords[1]]:.6f}", showarrow=True, arrowhead=1)
    fig.show()

    fig = px.imshow(ratio_map, color_continuous_scale='viridis', origin='lower',
                    labels={'color': 'Ratio '})
    fig.update_layout(title='3 Map of Ratio[%] ', coloraxis_colorbar=dict(title='Ratio (Area Above / Area Below) [%]'))
    fig.add_annotation(x=central_star_coords[1], y=central_star_coords[0], text=f"{ratio_map[central_star_coords[0], central_star_coords[1]]:.6f}", showarrow=True, arrowhead=1)
    fig.show()

# for one pixel(chack)
def plot_pixel_spectrum(cube, wavelength_min, wavelength_max, pixel_x, pixel_y, solid_angle):
    wavelength = cube.wave.coord()
    mask = (wavelength >= wavelength_min) & (wavelength <= wavelength_max)
    filtered_wavelengths = wavelength[mask]

    pixel_flux_density = cube.data[:, pixel_x, pixel_y] * solid_angle.value * 1e6
    pixel_flux_density_filtered = pixel_flux_density[mask]

    mask_start = (filtered_wavelengths >= 22.66) & (filtered_wavelengths <= 22.86)
    mask_end = (filtered_wavelengths >= 23.52) & (filtered_wavelengths <= 23.72)
    continuum_start = np.mean(pixel_flux_density_filtered[mask_start])
    continuum_end = np.mean(pixel_flux_density_filtered[mask_end])
    wavelengths = [22.76, 23.62]
    average_intensities = [continuum_start, continuum_end]
    pixel_continuum_line = np.interp(filtered_wavelengths, wavelengths, average_intensities)
    
    wavelength_condition = (filtered_wavelengths >= 22.76) & (filtered_wavelengths <= 23.62)

    total_area = np.trapz(pixel_flux_density_filtered, filtered_wavelengths)
    area_below_continuum = np.trapz(pixel_continuum_line, filtered_wavelengths)
    area_above_continuum = total_area - area_below_continuum

    plt.figure(figsize=(10, 6))
    plt.plot(filtered_wavelengths, pixel_flux_density_filtered, label='Spectrum (Jy)')
    plt.plot(wavelengths, average_intensities, label='Continuum', linestyle='--')
    plt.fill_between(filtered_wavelengths, pixel_flux_density_filtered, pixel_continuum_line, where=(pixel_flux_density_filtered > pixel_continuum_line) & wavelength_condition, color='green', alpha=0.3, label='Above Continuum')
    
    plt.text(22.5, max(pixel_flux_density_filtered) * 0.9, f'Area Above Continuum: {area_above_continuum:.6f}', color='green')
    plt.text(22.5, max(pixel_flux_density_filtered) * 0.8, f'Area Below Continuum: {area_below_continuum:.6f}', color='red')
    
    plt.xlabel('Wavelength (µm)')
    plt.ylabel('Flux Density (Jy)')
    plt.title(f'Spectrum and Continuum at Pixel ({pixel_x}, {pixel_y})')
    plt.legend()
    plt.show()

    return total_area, area_below_continuum, area_above_continuum

cube_path = '/Users/mary/Fits image of JWST/ngc6302_ch4-medium_s3d.fits'
obj1 = Cube(cube_path)

pixel_size = obj1.wcs.get_step(unit=u.arcsec)[0]
solid_angle = (pixel_size * u.arcsec).to(u.rad)**2

process_pixel_data(obj1, solid_angle,central_star_coords)

total_area, area_below_continuum, area_above_continuum = plot_pixel_spectrum(obj1, 22.76, 23.62, 43, 35, solid_angle)

area_above_continuum_map = np.loadtxt('23.71area_above_continuum.txt')
area_below_continuum_map = np.loadtxt('23.71area_below_continuum.txt')
ratio_map=np.loadtxt('23.71ratio_map.txt')
stored_area_above_continuum = area_above_continuum_map[43,35]
stored_area_below_continuum = area_below_continuum_map[43,35]
stored_ratio_map = ratio_map[43,35]

print(f"Calculated Area Above Continuum: {area_above_continuum}")
print(f"Stored Area Above Continuum: {stored_area_above_continuum}")
print(f"Calculated Area Below Continuum: {area_below_continuum}")
print(f"Stored Area Below Continuum: {stored_area_below_continuum}")
print(f"stored ratio_map: {stored_ratio_map}")
if np.isclose(area_above_continuum, stored_area_above_continuum) and np.isclose(area_below_continuum, stored_area_below_continuum):
    print("The calculated areas match the stored values")
# Out:
# <div>                            <div id="eaca9af6-b6d1-4fbf-ac08-2c44ab50abd1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eaca9af6-b6d1-4fbf-ac08-2c44ab50abd1")) {                    Plotly.newPlot(                        "eaca9af6-b6d1-4fbf-ac08-2c44ab50abd1",                        [{"coloraxis":"coloraxis","name":"0","z":[[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,0.0003424746563694802,0.00043565317451654643,0.0004987184281337719,0.00032943325912625394,0.0002371113444755036,0.00033311374292513234,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,0.00042018987021999465,0.00034343741105692226,0.0003664828499855494,0.0003308973196297048,0.00034902682841314765,0.0006631197783203095,0.0007977836926680582,0.000698914305824673,0.0007845656611251504,-0.0006210269446824557,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,0.0006472969965344993,0.0005867850019339801,0.00036484354194738465,0.0003426213371968091,0.00047333432121647676,0.0006239844255267772,0.0007703419025227257,0.0009511258407727541,0.0010338903582710916,0.0008937653060981064,0.00047732579489889824,0.00038846006171230647,0.0004850526740098572,0.0006406024693109604,0.0006182382023519704,-0.0014494302940228944,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,0.000655200385892311,0.0006923586071266672,0.0004303112524971231,0.0004191577383058946,0.00047378916228978975,0.0005970635124974795,0.0006856971708983162,0.0007080409054920894,0.0007288307426031836,0.0005845005527067423,0.0005366729967355242,0.0004947936941296404,0.0005789966192428931,0.0005378704015356521,0.00048253555561354397,0.0006735343213963227,0.0009233225410685683,0.000753687298816667,0.0005136433299491022,-0.002658807389376976,-0.0029924317863277688,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,0.0009163739611523936,0.0008778114279515952,0.0007811711630605137,0.0005755016485315227,0.0005879940413897021,0.000603461308341627,0.00048624392922885524,0.00048357276811802994,0.0006201836241128376,0.0 ...
# <div>                            <div id="58f0064a-cb9e-4eeb-9d7c-21bd4428b976" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58f0064a-cb9e-4eeb-9d7c-21bd4428b976")) {                    Plotly.newPlot(                        "58f0064a-cb9e-4eeb-9d7c-21bd4428b976",                        [{"coloraxis":"coloraxis","name":"0","z":[[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,0.005043773723723611,0.00481940548533424,0.004712687178921536,0.005012787142405176,0.0051754796280009275,0.005314582531751648,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,0.005413499482275848,0.005370479610072586,0.0052629778103235395,0.005316459273552412,0.005445336955377515,0.005330826227866885,0.005260654966646688,0.005784125028735072,0.0058634632389619155,0.005951780842059908,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,0.006121696749229404,0.005885554089547176,0.005730180754227517,0.005648895084440066,0.005637115600199296,0.005626903367280952,0.00557479575845771,0.005671007604703524,0.005799414844996474,0.006064497094773552,0.006529904349402174,0.006517971723324983,0.006589284155450369,0.006429235429153473,0.006682367504005861,0.00679589594002353,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,0.00799755199446993,0.007414529482643605,0.006683752186991531,0.006378160372839327,0.006191400491510058,0.005979212894821289,0.005932827369780549,0.0060810742646298915,0.006238210350976565,0.006561263802049164,0.006818416856905879,0.006835182055374945,0.006862607179514847,0.006881773139243487,0.007017872377531663,0.007091189772666352,0.007045933391256348,0.007490977092988153,0.007508954936487301,0.007929593017998657,0.007777033927443501,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,0.010451350218424122,0.009958315981127492,0.009569966299836457,0.00907509765442601,0.008199802111777116,0.007358359372258798,0.006812000157874371,0.006598343812998275,0.006528899910130526,0.006694096911104112,0.007032444087427902,0.007222937323248349,0.00726483788839 ...
# <div>                            <div id="2f6fcd97-6c43-4941-afa0-90612c07b09b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f6fcd97-6c43-4941-afa0-90612c07b09b")) {                    Plotly.newPlot(                        "2f6fcd97-6c43-4941-afa0-90612c07b09b",                        [{"coloraxis":"coloraxis","name":"0","z":[[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,6.790047990428984,9.039562573480628,10.582464084702945,6.571858125381905,4.581437113435028,6.267919275596243,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,7.76188991235196,6.394911367185703,6.9634124101127455,6.224016824050683,6.40964611140304,12.439343358330682,15.165102021062433,12.0833194710094,13.380584633187741,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,10.57381675457839,9.969919450338892,6.367051190806093,6.065280591607423,8.396746754665495,11.089304094950197,13.818298210369665,16.771725715618718,17.827494426667805,14.737665665111175,7.309843595834575,5.959830422739899,7.3612347345597895,9.963898139522751,9.25178392211079,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,8.192511737908834,9.337863026202587,6.438168867700246,6.57176542770593,7.65237465965046,9.985654015006014,11.55767946984238,11.643352386113023,11.683330660516894,8.908353182266433,7.870932622606773,7.238924876047043,8.436977435794676,7.815869408255155,6.875809784720851,9.498184973028406,13.10433252483433,10.061268235917417,6.840410340635033,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,8.767995923980877,8.814858150867877,8.162736822530539,6.341547721537136,7.1708320929499605,8.201030662034412,7.138049294769595,7.328699167894608,9.499052407749945,8.169355079581212,5.374266764045057,6.413345662410349,6.368961098166046,7.208355327970348,7.865883877056749,6.4681062007559,9.381505667509856,11.249390493274479,10.217663616427501,9.17377107072176,9.114626806790389,9.757338016050495,9.629421876104539,11.032229462680057,11.129872310924465,13.312169768726342 ...
# Calculated Area Above Continuum: 0.003724049372590993
# Stored Area Above Continuum: 0.006633
# Calculated Area Below Continuum: 0.21482977701512318
# Stored Area Below Continuum: 0.415176
# stored ratio_map: 1.597637
